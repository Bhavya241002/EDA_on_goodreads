# %%
! pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\bbhav\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\bbhav\anaconda3\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bbhav\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.3.1)

# %%
import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup

# %%
URL='https://www.goodreads.com/list/show/1381.Best_Series'

# %%
page=requests.get(URL)
page
# Out:
# <Response [200]>

# %%
page.status_code
# Out:
# 200

# %%
htmlcode=page.text

# %%
soup=BeautifulSoup(htmlcode)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="desktop withSiteHeaderTopFullImage">
#  <head>
#   <title>
#    Best Series (3036 books)
#   </title>
#   <meta content="3,039 books based on 10514 votes: Harry Potter and the Sorcerer's Stone by J.K. Rowling, The Lightning Thief by Rick Riordan, The Hunger Games by Suzanne..." name="description"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="https://www.goodreads.com/list/show/1381.Best_Series" rel="canonical"/>
#   <script type="text/javascript">
#    var ue_t0=window.ue_t0||+new Date();
#   </script>
#   <script type="text/javascript">
#    var ue_mid = "A1PQBFHBHS6YH1";
#     var ue_sn = "www.goodreads.com";
#     var ue_furl = "fls-na.amazon.com";
#     var ue_sid = "451-4345372-2975148";
#     var ue_id = "D4X15QT91YCPQ4KT945W";
#
#     (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i){var k={m:m,f:l,l:h,c:""+j,err:i,fromOnError:1,args:arguments};c.ueLogError(k);return false}b.skipTrace=1;e.onerror=b;function f(){c.uex("ld")}if(e.addEventListener){e.addEventListener("load",f,false)}else{if(e.attachEvent){e.attachEvent("onload",f)}}a.tag=d("tag");a.log=d("log");a.reset=d("rst");c.ue_csm=c;c.ue=a;c.ueLogError=d("err");c.ues=d("ues");c.uet=d("uet");c.uex=d("uex");c.uet("ue")})(window);(function(e,d){var a=e.ue||{};function c(g){if(!g){return}var f=d.head||d.getElementsByTagName("head")[0]||d.documentElement,h=d.createElement("script");h.async="async";h.src=g;f.insertBefore(h,f.firstChild)}function b(){var k=e.ue_cdn||"z-ecx.images-amazon.com",g=e.ue_cdns||"images-na.ssl-images-amazon.com",j="/images/G/01/csminstrumentation/",h=e.ue_file||"ue-full-11e51f253e8ad9d145f4ed644b40f692._V1_.js",f,i;if(h.indexOf("NSTRUMENTATION_FIL")>=0){return}if("ue_https" in e){f=e.ue_https}else{f=e.location&&e.location.protocol=="https:"?1:0}i=f?"https://":"http://";i+=f?g:k;i+=j;i+=h;c(i)}if(!e.ue_inline){if(a.loadUEFull){a.loadUEFull()}else{b()}}a.uels=c;e.ue=a})(window,document);
#
#     if (window.ue && window.ue.tag) { window.ue.tag('list:show:signed_out', ue.main_scope);window.ue.tag('list:show:signed_out:desktop', ue.main_scope); }
#   </script>
#   <!-- * Copied from https://info.analytics.a2z.com/#/docs/data_collection/csa/onboard */ -->
#   <script>
#    //<![CDATA[
#     !function(){function n(n,t){var r=i(n);return t&&(r=r("instance",t)),r}var r=[],c=0,i=function(t){return function(){var n=c++;return r.push([t,[].slice.call(arguments,0),n,{time:Date.now()}]),i(n)}};n._s=r,this.csa=n}();
#
#     if (window.csa) {
#       window.csa("Config", {
#         "Application": "GoodreadsMonolith",
#         "Events.SushiEndpoint": "https://unagi.amazon.com/1/events/com.amazon.csm.csa.prod",
#         "Events.Namespace": "csa",
#         "CacheDetection.RequestID": "D4X15QT91YCPQ4KT945W",
#         "ObfuscatedMarketplaceId": "A1PQBFHBHS6YH1"
#       });
#
#       window.csa("Events")("setEntity", {
#         session: { id: "451-4345372-2975148" },
#         page: {requestId: "D4X15QT91YCPQ4KT945W", meaningful: "interactive"}
#       });
#     }
#
#     var e = document.createElement("script"); e.src = "https://m.media-amazon.com/images/I/41mrkPcyPwL.js"; document.head.appendChild(e);
#   //]]>
#   </script>
#   <script type="text/javascript">
#    if (window.Mobvious === undefined) {
#           window.Mobvious = {};
#         }
#         window.Mobvious.device_type = 'desktop';
#   </script>
#   <script src="https://s.gr-assets.com/assets/webfontloader-c578336baa6da50a1f0d46c5164fc699.js">
#   </script>
#   <script>
#    //<![CDATA[
#
#   WebFont.load({
#     classes: false,
#     custom: {
#       families: ["Lato:n4,n7,i4", "Merriweather:n4,n7,i4"],
#       urls: ["https://s.gr-assets.com/assets/gr/fonts-e256f84093cc13b27f5b82343398031a.css"]
#     }
#   });
#
# //]]>
#   </script>
#   <link href="https://s.gr-assets.com/assets/goodreads-9106bbc46edb4445e180ef72108eae81.css" media="all" rel="stylesheet"/>
#   <style media="screen" type="text/css">
#    .bigTabs {
#       margin-bottom: 10px;
#     }
#
#     .list_read{
#       background-color: #D7D2C4;
#       float: left;
#     }
#   </style>
#   <link href="https://s.gr-assets.com/assets/common_images-f5630939f2056b14f661a80fa8503dca.css" media="screen" rel="stylesheet"/>
#   <script src="https://s.gr-assets.com/assets/desktop/libraries-c07ee2e4be9ade4a64546b3ec60b523b.js">
#   </script>
#   <script src="https://s.gr-assets.com/assets/application-7705fd5ee31b1f6622fa8f71b761190b.js">
#   </script>
#   <script>
#    //<![CDATA[
#     var gptAdSlots = gptAdSlots || [];
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     (function() {
#       var gads = document.createElement("script");
#       gads.async = true;
#       gads.type = "text/javascript";
#       var useSSL = "https:" == document.location.protocol;
#       gads.src = (useSSL ? "https:" : "http:") +
#       "//securepubads.g.doubleclick.net/tag/js/gpt.js";
#       var node = document.getElementsByTagName("script")[0];
#       node.parentNode.insertBefore(gads, node);
#     })();
#     // page settings
#   //]]>
#   </script>
#   <script>
#    //<![CDATA[
#     googletag.cmd.push(function() {
#       googletag.pubads().setTargeting("sid", "osid.a7de86b6415b2d5948e38bfd99c47e4f");
#     googletag.pubads().setTargeting("grsession", "osid.a7de86b6415b2d5948e38bfd99c47e4f");
#     googletag.pubads().setTargeting("surface", "desktop");
#     googletag.pubads().setTargeting("signedin", "false");
#     googletag.pubads().setTargeting("gr_author", "false");
#     googletag.pubads().setTargeting("author", []);
#     googletag.pubads().setTargeting("shelf", ["adult","best","children","childrens","fiction","series","youngadult"]);
#     googletag.pubads().setTargeting("tags", ["244","3723","142","68","1","201","35"]);
#     googletag.pubads().setTargeting("gtargeting", "1z141zd");
#     googletag.pubads().setTargeting("resource", "List_1381");
#       googletag.pubads().enableAsyncRendering();
#       googletag.pubads().enableSingleRequest();
#       googletag.pubads().collapseEmptyDivs(true);
#       googletag.pubads().disableInitialLoad();
#       googletag.enableServices();
#     });
#   //]]>
#   </script>
#   <script>
#    //<![CDATA[
#     ! function(a9, a, p, s, t, A, g) {
#       if (a[a9]) return;
#
#       function q(c, r) {
#         a[a9]._Q.push([c, r])
#       }
#       a[a9] = {
#       init: function() {
#         q("i", arguments)
#       },
#       fetchBids: function() {
#         q("f", arguments)
#       },
#       setDisplayBids: function() {},
#         _Q: []
#       };
#       A = p.createElement(s);
#       A.async = !0;
#       A.src = t;
#       g = p.getElementsByTagName(s)[0];
#       g.parentNode.insertBefore(A, g)
#     }("apstag", window, document, "script", "//c.amazon-adsystem.com/aax2/apstag.js");
#
#     apstag.init({
#       pubID: '3211', adServer: 'googletag', bidTimeout: 4e3, params: { aps_privacy: '1YN' }
#     });
#   //]]>
#   </script>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="a5Y1W8AVzk3YybSUnzV2hrT8b0jvg+Q/0X33uAUC6cx9huCFLFRVOy60cjvc4hT0ydkAyDFMYqDirdxy9jfVcg==" name="csrf-token"/>
#   <meta content="D4X15QT91YCPQ4KT945W" name="request-id"/>
#   <script defer="defer" src="https://s.gr-assets.com/assets/react_client_side/external_dependencies-2e2b90fafc.js">
#   </script>
#   <script defer="defer" src="https://s.gr-assets.com/assets/react_client_side/site_header-07ee155cb1.js">
#   </script>
#   <script defer="defer" src="https://s.gr-assets.com/assets/react_client_side/custom_react_ujs-b1220d5e0a4820e90b905c302fc5cb52.js">
#   </script>
#   <script>
#    //<![CDATA[
#     $grfb.init.done(function() {
#       if (this.auth.status === "not_authorized") {
#         // logged into Facebook user but not a GR app user; show FB button
#         $j("#generalRegPrompt").hide();
#       } else {
#         $j("#facebookRegPrompt").hide();
#       }
#       $j("#connectPrompt").show();
#     });
#   //]]>
#   </script>
#   <link href="/opensearch.xml" rel="search" title="Goodreads" type="application/opensearchdescription+xml"/>
#   <meta content="3,039 books based on 10514 votes: Harry Potter and the Sorcerer's Stone by J.K. Rowling, The Lightning Thief by Rick Riordan, The Hunger Games by Suzanne..." name="description"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="@goodreads" name="twitter:site"/>
#   <meta content="Best Series (3036 books)" name="twitter:title"/>
#   <meta content="3,039 books based on 10514 votes: Harry Potter and the Sorcerer's Stone by J.K. Rowling, The Lightning Thief by Rick Riordan, The Hunger Games by Suzanne..." name="twitter:description"/>
#   <meta content="cEf8XOH0pulh1aYQeZ1gkXHsQ3dMPSyIGGYqmF53690=" name="verify-v1"/>
#   <meta content="PfFjeZ9OK1RrUrKlmAPn_iZJ_vgHaZO1YQ-QlG2VsJs" name="google-site-verification"/>
#   <meta content="app-id=355833469" name="apple-itunes-app"/>
#  </head>
#  <body class="">
#   <div data-react-class="ReactComponents.StoresInitializer" data-react-props="{}">
#    <noscript data-react-checksum="-1426976451" data-reactid=".9m0lzticdc">
#    </noscript>
#   </div>
#   <div class="content">
#    <script>
#     //<![CDATA[
#     var initializeGrfb = function() {
#       $grfb.initialize({
#         appId: "2415071772"
#       });
#     };
#     if (typeof $grfb !== "undefined") {
#       initializeGrfb();
#     } else {
#       window.addEventListener("DOMContentLoaded", function() {
#         if (typeof $grfb !== "undefined") {
#           initializeGrfb();
#         }
#       });
#     }
#   //]]>
#    </script>
#    <script>
#     //<![CDATA[
#     function loadScript(url, callback) {
#       var script = document.createElement("script");
#       script.type = "text/javascript";
#
#       if (script.readyState) {  //Internet Explorer
#           script.onreadystatechange = function() {
#             if (script.readyState == "loaded" ||
#                     script.readyState == "complete") {
#               script.onreadystatechange = null;
#               callback();
#             }
#           };
#       } else {  //Other browsers
#         script.onload = function() {
#           callback();
#         };
#       }
#
#       script.src = url;
#       document.getElementsByTagName("head")[0].appendChild(script);
#     }
#
#     function initAppleId() {
#       AppleID.auth.init({
#         clientId : 'com.goodreads.app',
#         scope : 'name email',
#         redirectURI: 'https://www.goodreads.com/apple_users/sign_in_with_apple_web',
#         state: 'apple_oauth_state_6b14c160-7001-4571-b459-bd8dbd1ebb48'
#       });
#     }
#
#     var initializeSiwa = function() {
#       var APPLE_SIGN_IN_JS_URL =  "https://appleid.cdn-apple.com/appleauth/static/jsapi/appleid/1/en_US/appleid.auth.js"
#       loadScript(APPLE_SIGN_IN_JS_URL, initAppleId);
#     };
#     if (typeof AppleID !== "undefined") {
#       initAppleId();
#     } else {
#       initializeSiwa();
#     }
#   //]]>
#    </script>
#    <div class="siteHeader">
#     <div data-react-class="ReactComponents.HeaderStoreConnector" data-react-props='{"myBooksUrl":"/review/list?ref=nav_mybooks","browseUrl":"/book?ref=nav_brws","recommendationsUrl":"/recommendations?ref=nav_brws_recs","choiceAwardsUrl":"/choiceawards?ref=nav_brws_gca","genresIndexUrl":"/genres?ref=nav_brws_genres","giveawayUrl":"/giveaway?ref=nav_brws_giveaways","exploreUrl":"/book?ref=nav_brws_explore","homeUrl":"/?ref=nav_home","listUrl":"/list?ref=nav_brws_lists","newsUrl":"/news?ref=nav_brws_news","communityUrl":"/group?ref=nav_comm","groupsUrl":"/group?ref=nav_comm_groups","quotesUrl":"/quotes?ref=nav_comm_quotes","featuredAskAuthorUrl":"/ask_the_author?ref=nav_comm_askauthor","autocompleteUrl":"/book/auto_complete","defaultLogoActionUrl":"/","topFullImage":{"clickthroughUrl":"https://www.goodreads.com/blog/show/2461?ref=bhm2023_eb","altText":"Celebrate Black History Month with New Books","backgroundColor":"#B7C0FD","xs":{"1x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1674770146i/219.jpg","2x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1674770152i/220.jpg"},"md":{"1x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1674770135i/217.jpg","2x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1674770140i/218.jpg"}},"logo":{"clickthroughUrl":"/","altText":"Goodreads Home"},"searchPath":"/search","newReleasesUrl":"/book/popular_by_date/2023/2?ref=nav_brws_newrels","signInUrl":"/user/sign_in","signUpUrl":"/user/sign_up","signInWithReturnUrl":true,"deployServices":[],"defaultLogoAltText":"Goodreads Home","mobviousDeviceType":"desktop"}'>
#      <header data-react-checksum="33230961" data-reactid=".ho4vma3ytw">
#       <div class="siteHeader__topFullImageContainer" data-reactid=".ho4vma3ytw.0" style="background-color:#B7C0FD;">
#        <a class="siteHeader__topFullImageLink" data-reactid=".ho4vma3ytw.0.0" href="https://www.goodreads.com/blog/show/2461?ref=bhm2023_eb">
#         <picture data-reactid=".ho4vma3ytw.0.0.0">
#          <source data-reactid=".ho4vma3ytw.0.0.0.0" media="(min-width: 768px)" srcset="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1674770135i/217.jpg 1x, https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1674770140i/218.jpg 2x"/>
#          <img alt="Celebrate Black History Month with New Books" class="siteHeader__topFullImage" data-reactid=".ho4vma3ytw.0.0.0.1" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1674770146i/219.jpg" srcset="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1674770152i/220.jpg 2x"/>
#         </picture>
#        </a>
#       </div>
#       <div class="siteHeader__topLine gr-box gr-box--withShadow" data-reactid=".ho4vma3ytw.1">
#        <div class="siteHeader__contents" data-reactid=".ho4vma3ytw.1.0">
#         <div class="siteHeader__topLevelItem siteHeader__topLevelItem--searchIcon" data-reactid=".ho4vma3ytw.1.0.0">
#          <button aria-label="Toggle search" class="siteHeader__searchIcon gr-iconButton" data-reactid=".ho4vma3ytw.1.0.0.0" data-ux-click="true" type="button">
#          </button>
#         </div>
#         <a aria-label="Goodreads Home" class="siteHeader__logo" data-reactid=".ho4vma3ytw.1.0.1" href="/" title="Goodreads Home">
#         </a>
#         <nav class="siteHeader__primaryNavInline" data-reactid=".ho4vma3ytw.1.0.2">
#          <ul class="siteHeader__menuList" data-reactid=".ho4vma3ytw.1.0.2.0" role="menu">
#           <li class="siteHeader__topLevelItem siteHeader__topLevelItem--home" data-reactid=".ho4vma3ytw.1.0.2.0.0">
#            <a class="siteHeader__topLevelLink" data-reactid=".ho4vma3ytw.1.0.2.0.0.0" href="/?ref=nav_home">
#             Home
#            </a>
#           </li>
#           <li class="siteHeader__topLevelItem" data-reactid=".ho4vma3ytw.1.0.2.0.1">
#            <a class="siteHeader__topLevelLink" data-reactid=".ho4vma3ytw.1.0.2.0.1.0" href="/review/list?ref=nav_mybooks">
#             My Books
#            </a>
#           </li>
#           <li class="siteHeader__topLevelItem" data-reactid=".ho4vma3ytw.1.0.2.0.2">
#            <div class="primaryNavMenu primaryNavMenu--siteHeaderBrowseMenu ignore-react-onclickoutside" data-reactid=".ho4vma3ytw.1.0.2.0.2.0">
#             <a aria-expanded="false" aria-haspopup="true" class="primaryNavMenu__trigger primaryNavMenu__trigger--siteHeaderBrowseMenu" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.0" data-ux-click="true" href="/book?ref=nav_brws" role="button">
#              <span data-reactid=".ho4vma3ytw.1.0.2.0.2.0.0.0">
#               Browse ▾
#              </span>
#             </a>
#             <div class="primaryNavMenu__menu gr-box gr-box--withShadowLarge wide" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1" role="menu">
#              <div class="siteHeader__browseMenuDropdown" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0">
#               <ul class="siteHeader__subNav" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0">
#                <li aria-label="Recommendations" class="menuLink" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.0" role="menuitem Recommendations">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.0.0" href="/recommendations?ref=nav_brws_recs">
#                  Recommendations
#                 </a>
#                </li>
#                <li aria-label="Choice Awards" class="menuLink" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.1" role="menuitem Choice Awards">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.1.0" href="/choiceawards?ref=nav_brws_gca">
#                  Choice Awards
#                 </a>
#                </li>
#                <li aria-label="Genres" class="menuLink" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.2" role="menuitem Genres">
#                 <a class="siteHeader__subNavLink siteHeader__subNavLink--genresIndex" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.2.0" href="/genres?ref=nav_brws_genres">
#                  Genres
#                 </a>
#                </li>
#                <li aria-label="Giveaways" class="menuLink" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.3" role="menuitem Giveaways">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.3.0" href="/giveaway?ref=nav_brws_giveaways">
#                  Giveaways
#                 </a>
#                </li>
#                <li aria-label="New Releases" class="menuLink" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.4" role="menuitem New Releases">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.4.0" href="/book/popular_by_date/2023/2?ref=nav_brws_newrels">
#                  New Releases
#                 </a>
#                </li>
#                <li aria-label="Lists" class="menuLink" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.5" role="menuitem Lists">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.5.0" href="/list?ref=nav_brws_lists">
#                  Lists
#                 </a>
#                </li>
#                <li aria-label="Explore" class="menuLink" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.6" role="menuitem Explore">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.6.0" href="/book?ref=nav_brws_explore">
#                  Explore
#                 </a>
#                </li>
#                <li aria-label="News &amp; Interviews" class="menuLink" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.7" role="menuitem News &amp; Interviews">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.0.7.0" href="/news?ref=nav_brws_news">
#                  News &amp; Interviews
#                 </a>
#                </li>
#               </ul>
#               <div class="siteHeader__spotlight siteHeader__spotlight--withoutSubMenu" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1">
#                <div class="genreListContainer" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0">
#                 <div class="siteHeader__heading siteHeader__title" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.0">
#                  Genres
#                 </div>
#                 <ul class="genreList" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0">
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Art" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Art.0" href="/genres/art">
#                    Art
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Biography" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Biography.0" href="/genres/biography">
#                    Biography
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Business" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Business.0" href="/genres/business">
#                    Business
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Children's" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Children's.0" href="/genres/children-s">
#                    Children's
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Christian" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Christian.0" href="/genres/christian">
#                    Christian
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Classics" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Classics.0" href="/genres/classics">
#                    Classics
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Comics" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Comics.0" href="/genres/comics">
#                    Comics
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Cookbooks" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Cookbooks.0" href="/genres/cookbooks">
#                    Cookbooks
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Ebooks" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Ebooks.0" href="/genres/ebooks">
#                    Ebooks
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Fantasy" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Fantasy.0" href="/genres/fantasy">
#                    Fantasy
#                   </a>
#                  </li>
#                 </ul>
#                 <ul class="genreList" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1">
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Fiction" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Fiction.0" href="/genres/fiction">
#                    Fiction
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Graphic Novels" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Graphic Novels.0" href="/genres/graphic-novels">
#                    Graphic Novels
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Historical Fiction" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Historical Fiction.0" href="/genres/historical-fiction">
#                    Historical Fiction
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$History" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$History.0" href="/genres/history">
#                    History
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Horror" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Horror.0" href="/genres/horror">
#                    Horror
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Memoir" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Memoir.0" href="/genres/memoir">
#                    Memoir
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Music" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Music.0" href="/genres/music">
#                    Music
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Mystery" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Mystery.0" href="/genres/mystery">
#                    Mystery
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Nonfiction" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Nonfiction.0" href="/genres/non-fiction">
#                    Nonfiction
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Poetry" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Poetry.0" href="/genres/poetry">
#                    Poetry
#                   </a>
#                  </li>
#                 </ul>
#                 <ul class="genreList" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2">
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Psychology" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Psychology.0" href="/genres/psychology">
#                    Psychology
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Romance" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Romance.0" href="/genres/romance">
#                    Romance
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Science" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Science.0" href="/genres/science">
#                    Science
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Science Fiction" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Science Fiction.0" href="/genres/science-fiction">
#                    Science Fiction
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Self Help" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Self Help.0" href="/genres/self-help">
#                    Self Help
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Sports" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Sports.0" href="/genres/sports">
#                    Sports
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Thriller" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Thriller.0" href="/genres/thriller">
#                    Thriller
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Travel" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Travel.0" href="/genres/travel">
#                    Travel
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Young Adult" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Young Adult.0" href="/genres/young-adult">
#                    Young Adult
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.1" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.2.0.2.0.1.0.1.0.1:$genreList2.1.0" href="/genres">
#                    More Genres
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </li>
#           <li class="siteHeader__topLevelItem siteHeader__topLevelItem--community" data-reactid=".ho4vma3ytw.1.0.2.0.3">
#            <div class="primaryNavMenu ignore-react-onclickoutside" data-reactid=".ho4vma3ytw.1.0.2.0.3.0">
#             <a aria-expanded="false" aria-haspopup="true" class="primaryNavMenu__trigger" data-reactid=".ho4vma3ytw.1.0.2.0.3.0.0" data-ux-click="true" href="/group?ref=nav_comm" role="button">
#              <span data-reactid=".ho4vma3ytw.1.0.2.0.3.0.0.0">
#               Community ▾
#              </span>
#             </a>
#             <div class="primaryNavMenu__menu gr-box gr-box--withShadowLarge" data-reactid=".ho4vma3ytw.1.0.2.0.3.0.1" role="menu">
#              <ul class="siteHeader__subNav" data-reactid=".ho4vma3ytw.1.0.2.0.3.0.1.0">
#               <li aria-label="Groups" class="menuLink" data-reactid=".ho4vma3ytw.1.0.2.0.3.0.1.0.0" role="menuitem Groups">
#                <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.2.0.3.0.1.0.0.0" href="/group?ref=nav_comm_groups">
#                 Groups
#                </a>
#               </li>
#               <li aria-label="Quotes" class="menuLink" data-reactid=".ho4vma3ytw.1.0.2.0.3.0.1.0.2" role="menuitem Quotes">
#                <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.2.0.3.0.1.0.2.0" href="/quotes?ref=nav_comm_quotes">
#                 Quotes
#                </a>
#               </li>
#               <li aria-label="Ask the Author" class="menuLink" data-reactid=".ho4vma3ytw.1.0.2.0.3.0.1.0.3" role="menuitem Ask the Author">
#                <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.2.0.3.0.1.0.3.0" href="/ask_the_author?ref=nav_comm_askauthor">
#                 Ask the Author
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </li>
#          </ul>
#         </nav>
#         <div accept-charset="UTF-8" class="searchBox searchBox--navbar" data-reactid=".ho4vma3ytw.1.0.3">
#          <form action="/search" aria-label="Search for books to add to your shelves" autocomplete="off" class="searchBox__form" data-reactid=".ho4vma3ytw.1.0.3.0" role="search">
#           <input aria-controls="searchResults" aria-label="Search books" autocomplete="off" class="searchBox__input searchBox__input--navbar" data-reactid=".ho4vma3ytw.1.0.3.0.0" name="q" placeholder="Search books" type="text"/>
#           <input data-reactid=".ho4vma3ytw.1.0.3.0.1" name="qid" type="hidden" value=""/>
#           <button aria-label="Search" class="searchBox__icon--magnifyingGlass gr-iconButton searchBox__icon searchBox__icon--navbar" data-reactid=".ho4vma3ytw.1.0.3.0.2" type="submit">
#           </button>
#          </form>
#         </div>
#         <ul class="siteHeader__personal" data-reactid=".ho4vma3ytw.1.0.4">
#          <li class="siteHeader__topLevelItem siteHeader__topLevelItem--signedOut" data-reactid=".ho4vma3ytw.1.0.4.0">
#           <a class="siteHeader__topLevelLink" data-reactid=".ho4vma3ytw.1.0.4.0.0" href="/user/sign_in?returnurl=undefined" rel="nofollow">
#            Sign In
#           </a>
#          </li>
#          <li class="siteHeader__topLevelItem siteHeader__topLevelItem--signedOut" data-reactid=".ho4vma3ytw.1.0.4.1">
#           <a class="siteHeader__topLevelLink" data-reactid=".ho4vma3ytw.1.0.4.1.0" href="/user/sign_up" rel="nofollow">
#            Join
#           </a>
#          </li>
#         </ul>
#         <div class="siteHeader__topLevelItem siteHeader__topLevelItem--signUp" data-reactid=".ho4vma3ytw.1.0.5">
#          <a class="gr-button gr-button--dark" data-reactid=".ho4vma3ytw.1.0.5.0" href="/user/sign_up" rel="nofollow">
#           Sign up
#          </a>
#         </div>
#         <div class="modal modal--overlay modal--drawer" data-reactid=".ho4vma3ytw.1.0.7" tabindex="0">
#          <div data-reactid=".ho4vma3ytw.1.0.7.0">
#           <div class="modal__close" data-reactid=".ho4vma3ytw.1.0.7.0.0">
#            <button class="gr-iconButton" data-reactid=".ho4vma3ytw.1.0.7.0.0.0" type="button">
#             <img alt="Dismiss" data-reactid=".ho4vma3ytw.1.0.7.0.0.0.0" src="//s.gr-assets.com/assets/gr/icons/icon_close_white-dbf4152deeef5bd3915d5d12210bf05f.svg"/>
#            </button>
#           </div>
#           <div class="modal__content" data-reactid=".ho4vma3ytw.1.0.7.0.1">
#            <div class="personalNavDrawer" data-reactid=".ho4vma3ytw.1.0.7.0.1.0">
#             <div class="personalNavDrawer__personalNavContainer" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.0">
#              <noscript data-reactid=".ho4vma3ytw.1.0.7.0.1.0.0.0">
#              </noscript>
#             </div>
#             <div class="personalNavDrawer__profileAndLinksContainer" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1">
#              <div class="personalNavDrawer__profileContainer gr-mediaFlexbox gr-mediaFlexbox--alignItemsCenter" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.0">
#               <div class="gr-mediaFlexbox__media" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.0.0">
#                <img class="circularIcon circularIcon--large circularIcon--border" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.0.0.0"/>
#               </div>
#               <div class="gr-mediaFlexbox__desc" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.0.1">
#                <a class="gr-hyperlink gr-hyperlink--bold" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.0.1.0">
#                </a>
#                <div class="u-displayBlock" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.0.1.1">
#                 <a class="gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.0.1.1.0">
#                  View profile
#                 </a>
#                </div>
#               </div>
#              </div>
#              <div class="personalNavDrawer__profileMenuContainer" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1">
#               <ul data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0">
#                <li aria-label="Profile" class="menuLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.0" role="menuitem Profile">
#                 <span data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.0.0">
#                  <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.0.0.0">
#                   Profile
#                  </a>
#                 </span>
#                </li>
#                <li aria-label="Friends" class="menuLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.3" role="menuitem Friends">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.3.0">
#                  Friends
#                 </a>
#                </li>
#                <li aria-label="Groups" class="menuLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.4" role="menuitem Groups">
#                 <span data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.4.0">
#                  <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.4.0.0">
#                   <span data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.4.0.0.0">
#                    Groups
#                   </span>
#                  </a>
#                 </span>
#                </li>
#                <li aria-label="Discussions" class="menuLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.5" role="menuitem Discussions">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.5.0">
#                  Discussions
#                 </a>
#                </li>
#                <li aria-label="Comments" class="menuLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.6" role="menuitem Comments">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.6.0">
#                  Comments
#                 </a>
#                </li>
#                <li aria-label="Reading Challenge" class="menuLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.7" role="menuitem Reading Challenge">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.7.0">
#                  Reading Challenge
#                 </a>
#                </li>
#                <li aria-label="Kindle Notes &amp; Highlights" class="menuLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.8" role="menuitem Kindle Notes &amp; Highlights">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.8.0">
#                  Kindle Notes &amp; Highlights
#                 </a>
#                </li>
#                <li aria-label="Quotes" class="menuLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.9" role="menuitem Quotes">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.9.0">
#                  Quotes
#                 </a>
#                </li>
#                <li aria-label="Favorite genres" class="menuLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.a" role="menuitem Favorite genres">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.a.0">
#                  Favorite genres
#                 </a>
#                </li>
#                <li aria-label="Friends' recommendations" class="menuLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.b" role="menuitem Friends' recommendations">
#                 <span data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.b.0">
#                  <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.b.0.0">
#                   <span data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.b.0.0.0">
#                    Friends’ recommendations
#                   </span>
#                  </a>
#                 </span>
#                </li>
#                <li aria-label="Account settings" class="menuLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.c" role="menuitem Account settings">
#                 <a class="siteHeader__subNavLink u-topGrayBorder" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.c.0">
#                  Account settings
#                 </a>
#                </li>
#                <li aria-label="Help" class="menuLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.d" role="menuitem Help">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.d.0">
#                  Help
#                 </a>
#                </li>
#                <li aria-label="Sign out" class="menuLink" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.e" role="menuitem Sign out">
#                 <a class="siteHeader__subNavLink" data-method="POST" data-reactid=".ho4vma3ytw.1.0.7.0.1.0.1.1.0.e.0">
#                  Sign out
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="headroom-wrapper" data-reactid=".ho4vma3ytw.2">
#        <div class="headroom headroom--unfixed" data-reactid=".ho4vma3ytw.2.0" style="position:relative;top:0;left:0;right:0;z-index:1;-webkit-transform:translateY(0);-ms-transform:translateY(0);transform:translateY(0);">
#         <nav class="siteHeader__primaryNavSeparateLine gr-box gr-box--withShadow" data-reactid=".ho4vma3ytw.2.0.0">
#          <ul class="siteHeader__menuList" data-reactid=".ho4vma3ytw.2.0.0.0" role="menu">
#           <li class="siteHeader__topLevelItem siteHeader__topLevelItem--home" data-reactid=".ho4vma3ytw.2.0.0.0.0">
#            <a class="siteHeader__topLevelLink" data-reactid=".ho4vma3ytw.2.0.0.0.0.0" href="/?ref=nav_home">
#             Home
#            </a>
#           </li>
#           <li class="siteHeader__topLevelItem" data-reactid=".ho4vma3ytw.2.0.0.0.1">
#            <a class="siteHeader__topLevelLink" data-reactid=".ho4vma3ytw.2.0.0.0.1.0" href="/review/list?ref=nav_mybooks">
#             My Books
#            </a>
#           </li>
#           <li class="siteHeader__topLevelItem" data-reactid=".ho4vma3ytw.2.0.0.0.2">
#            <div class="primaryNavMenu primaryNavMenu--siteHeaderBrowseMenu ignore-react-onclickoutside" data-reactid=".ho4vma3ytw.2.0.0.0.2.0">
#             <a aria-expanded="false" aria-haspopup="true" class="primaryNavMenu__trigger primaryNavMenu__trigger--siteHeaderBrowseMenu" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.0" data-ux-click="true" href="/book?ref=nav_brws" role="button">
#              <span data-reactid=".ho4vma3ytw.2.0.0.0.2.0.0.0">
#               Browse ▾
#              </span>
#             </a>
#             <div class="primaryNavMenu__menu gr-box gr-box--withShadowLarge wide" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1" role="menu">
#              <div class="siteHeader__browseMenuDropdown" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0">
#               <ul class="siteHeader__subNav" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0">
#                <li aria-label="Recommendations" class="menuLink" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.0" role="menuitem Recommendations">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.0.0" href="/recommendations?ref=nav_brws_recs">
#                  Recommendations
#                 </a>
#                </li>
#                <li aria-label="Choice Awards" class="menuLink" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.1" role="menuitem Choice Awards">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.1.0" href="/choiceawards?ref=nav_brws_gca">
#                  Choice Awards
#                 </a>
#                </li>
#                <li aria-label="Genres" class="menuLink" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.2" role="menuitem Genres">
#                 <a class="siteHeader__subNavLink siteHeader__subNavLink--genresIndex" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.2.0" href="/genres?ref=nav_brws_genres">
#                  Genres
#                 </a>
#                </li>
#                <li aria-label="Giveaways" class="menuLink" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.3" role="menuitem Giveaways">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.3.0" href="/giveaway?ref=nav_brws_giveaways">
#                  Giveaways
#                 </a>
#                </li>
#                <li aria-label="New Releases" class="menuLink" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.4" role="menuitem New Releases">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.4.0" href="/book/popular_by_date/2023/2?ref=nav_brws_newrels">
#                  New Releases
#                 </a>
#                </li>
#                <li aria-label="Lists" class="menuLink" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.5" role="menuitem Lists">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.5.0" href="/list?ref=nav_brws_lists">
#                  Lists
#                 </a>
#                </li>
#                <li aria-label="Explore" class="menuLink" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.6" role="menuitem Explore">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.6.0" href="/book?ref=nav_brws_explore">
#                  Explore
#                 </a>
#                </li>
#                <li aria-label="News &amp; Interviews" class="menuLink" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.7" role="menuitem News &amp; Interviews">
#                 <a class="siteHeader__subNavLink" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.0.7.0" href="/news?ref=nav_brws_news">
#                  News &amp; Interviews
#                 </a>
#                </li>
#               </ul>
#               <div class="siteHeader__spotlight siteHeader__spotlight--withoutSubMenu" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.1">
#                <div class="genreListContainer" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.1.0">
#                 <div class="siteHeader__heading siteHeader__title" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.1.0.0">
#                  Genres
#                 </div>
#                 <ul class="genreList" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.1.0.1:$genreList0">
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.1.0.1:$genreList0.0:$Art" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.1.0.1:$genreList0.0:$Art.0" href="/genres/art">
#                    Art
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.1.0.1:$genreList0.0:$Biography" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".ho4vma3ytw.2.0.0.0.2.0.1.0.1.0.1:$genreList0.0:$Biography.0" href="/genres/biography">
#                    Biography
#                   </a>
#                  </li>
# ...
#              Celebrate Black History Month with New &amp; Upcoming Books by Black Authors
#             </a>
#            </div>
#            <div class="newsPreview__excerpt" data-reactid=".1xaij1dtb1k.1:$kca=2//blog/amzn1=1gr=1blog=1v3=1OIZn_O9C45shJITc.1.1">
#             In celebration of Black History Month in the United States, we’ve gathered below a broad sampling of books by Black authors hitting shelves in...
#            </div>
#            <div class="newsPreview__readMore" data-reactid=".1xaij1dtb1k.1:$kca=2//blog/amzn1=1gr=1blog=1v3=1OIZn_O9C45shJITc.1.2">
#             <a data-reactid=".1xaij1dtb1k.1:$kca=2//blog/amzn1=1gr=1blog=1v3=1OIZn_O9C45shJITc.1.2.0" href="https://www.goodreads.com/blog/show/2461-celebrate-black-history-month-with-new-upcoming-books-by-black-authors?ref=list-show">
#              Read more...
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <ul class="listHeaderLinks stacked">
#         <li>
#          <a class="actionLinkLite" href="/list/new">
#           Create New List
#          </a>
#         </li>
#         <li>
#          <a class="actionLinkLite" href="/list">
#           All Lists
#          </a>
#         </li>
#         <li>
#          <a class="actionLinkLite" href="/list/created">
#           Lists I Created
#          </a>
#         </li>
#         <li>
#          <a class="actionLinkLite" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F1381.Best_Series">
#           Lists I've Voted On
#          </a>
#         </li>
#         <li>
#          <a class="actionLinkLite" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F1381.Best_Series">
#           Lists I've Liked
#          </a>
#         </li>
#        </ul>
#        <p class="mediumText">
#         Anyone can add books to this list.
#        </p>
#        <p>
#        </p>
#        <div data-react-class="ReactComponents.GoogleBannerAd" data-react-props='{"adId":"","className":"googleBannerAd--mediumRectangle"}'>
#        </div>
#        <div data-react-class="ReactComponents.GoogleFeaturedContentModule" data-react-props='{"adId":"","trackingOptions":{"enableTracking":true,"adId":""},"isMobile":false,"isInline":false,"hasBottomBorder":false}'>
#        </div>
#        <div class="clearFloats bigBox">
#         <div class="h2Container gradientHeaderContainer">
#          <h2 class="brownBackground">
#           <div class="extraHeader">
#            <span id="saving_notice" style="display:none">
#             Saving
#             <img alt="Loading trans" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
#            </span>
#           </div>
#           <a href="/list/show/1381.Best_Series">
#            My Votes
#           </a>
#          </h2>
#         </div>
#         <div class="bigBoxBody">
#          <div class="bigBoxContent containerWithHeaderContent">
#           <a class="actionLink" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F1381.Best_Series">
#            vote now
#           </a>
#           <div class="clear">
#           </div>
#          </div>
#         </div>
#         <div class="bigBoxBottom">
#         </div>
#        </div>
#        <br class="clear"/>
#        <br/>
#        <div class="clearFloats bigBox">
#         <div class="h2Container gradientHeaderContainer">
#          <h2 class="brownBackground">
#           <a href="/list/invite/1381.Best_Series">
#            Friends Votes
#           </a>
#          </h2>
#         </div>
#         <div class="bigBoxBody">
#          <div class="bigBoxContent containerWithHeaderContent">
#           <a class="actionLink" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F1381.Best_Series">
#            get your friends to vote
#           </a>
#           <div class="clear">
#           </div>
#          </div>
#         </div>
#         <div class="bigBoxBottom">
#         </div>
#        </div>
#        <div data-react-class="ReactComponents.GoogleBannerAd" data-react-props='{"adId":"","className":"googleBannerAd--mediumRectangle"}'>
#        </div>
#       </div>
#       <div id="chooseExplanation" style="display:none">
#        <h2>
#         How to Vote
#        </h2>
#        <p>
#         To vote on existing books from the list, beside each book there is a link
#         <span class="gr-button gr-button--small">
#          vote for this book
#         </span>
#         clicking it will add that book to your votes.
#        </p>
#        <p>
#         To vote on books not in the list or books you couldn't find in the list, you can click on the tab
#         <span class="bigTabs">
#          <span class="tab">
#           add books to this list
#          </span>
#         </span>
#         and then choose from your books, or simply search.
#        </p>
#       </div>
#      </div>
#      <div class="clear">
#      </div>
#     </div>
#     <div class="clear">
#     </div>
#    </div>
#    <div data-react-class="ReactComponents.GooglePageSkin" data-react-props='{"adId":"","trackingOptions":{"enableTracking":true,"adId":""}}'>
#    </div>
#    <div class="clear">
#    </div>
#    <footer class="responsiveSiteFooter">
#     <div class="responsiveSiteFooter__contents gr-container-fluid">
#      <div class="gr-row">
#       <div class="gr-col gr-col-md-8 gr-col-lg-6">
#        <div class="gr-row">
#         <div class="gr-col-md-3 gr-col-lg-4">
#          <h3 class="responsiveSiteFooter__heading">
#           Company
#          </h3>
#          <ul class="responsiveSiteFooter__linkList">
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/about/us">
#             About us
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/jobs">
#             Careers
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/about/terms">
#             Terms
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/about/privacy">
#             Privacy
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="https://help.goodreads.com/s/article/Goodreads-Interest-Based-Ads-Notice">
#             Interest Based Ads
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/adprefs">
#             Ad Preferences
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/help?action_type=help_web_footer">
#             Help
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="gr-col-md-4 gr-col-lg-4">
#          <h3 class="responsiveSiteFooter__heading">
#           Work with us
#          </h3>
#          <ul class="responsiveSiteFooter__linkList">
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/author/program">
#             Authors
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/advertisers">
#             Advertise
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/news?content_type=author_blogs">
#             Authors &amp; ads blog
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/api">
#             API
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="gr-col-md-5 gr-col-lg-4">
#          <h3 class="responsiveSiteFooter__heading">
#           Connect
#          </h3>
#          <div class="responsiveSiteFooter__socialLinkWrapper">
#           <a class="responsiveSiteFooter__socialLink" href="https://www.facebook.com/Goodreads/" rel="noopener noreferrer">
#            <img alt="Goodreads on Facebook" src="https://s.gr-assets.com/assets/site_footer/footer_facebook-ea4ab848f8e86c5f5c98311bc9495a1b.svg"/>
#           </a>
#           <a class="responsiveSiteFooter__socialLink" href="https://twitter.com/goodreads" rel="noopener noreferrer">
#            <img alt="Goodreads on Twitter" src="https://s.gr-assets.com/assets/site_footer/footer_twitter-126b3ee80481a763f7fccb06ca03053c.svg"/>
#           </a>
#          </div>
#          <div class="responsiveSiteFooter__socialLinkWrapper">
#           <a class="responsiveSiteFooter__socialLink" href="https://www.instagram.com/goodreads/" rel="noopener noreferrer">
#            <img alt="Goodreads on Instagram" src="https://s.gr-assets.com/assets/site_footer/footer_instagram-d59e3887020f12bcdb12e6c539579d85.svg"/>
#           </a>
#           <a class="responsiveSiteFooter__socialLink" href="https://www.linkedin.com/company/goodreads-com/" rel="noopener noreferrer">
#            <img alt="Goodreads on LinkedIn" src="https://s.gr-assets.com/assets/site_footer/footer_linkedin-5b820f4703eff965672594ef4d10e33c.svg"/>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="gr-col gr-col-md-4 gr-col-lg-6 responsiveSiteFooter__appLinksColumn">
#        <div class="responsiveSiteFooter__appLinksColumnContents">
#         <div class="responsiveSiteFooter__appLinksColumnBadges">
#          <a href="https://itunes.apple.com/app/apple-store/id355833469?pt=325668&amp;ct=mw_footer&amp;mt=8">
#           <img alt="Download app for iOS" src="https://s.gr-assets.com/assets/app/badge-ios-desktop-homepage-6ac7ae16eabce57f6c855361656a7540.svg"/>
#          </a>
#          <a href="https://play.google.com/store/apps/details?id=com.goodreads&amp;utm_source=mw_footer&amp;pcampaignid=MKT-Other-global-all-co-prtnr-py-PartBadge-Mar2515-1">
#           <img alt="Download app for Android" src="https://s.gr-assets.com/assets/app/badge-android-desktop-home-0f517cbae4d56c88a128d27a7bea1118.png" srcset="https://s.gr-assets.com/assets/app/badge-android-desktop-home-2x-e31514e1fb4dddecf9293aa526a64cfe.png 2x"/>
#          </a>
#         </div>
#         <ul class="responsiveSiteFooter__linkList">
#          <li class="responsiveSiteFooter__linkListItem">
#           ©
# 2023
# Goodreads, Inc.
#          </li>
#          <li class="responsiveSiteFooter__linkListItem">
#           <a class="responsiveSiteFooter__link" href="/toggle_mobile">
#            Mobile version
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#    </footer>
#    <script>
#     //<![CDATA[
# if (typeof window.uet == 'function') { window.uet('be'); }
# //]]>
#    </script>
#   </div>
#   <!--
# This partial loads on almost every page view.  The associated React component makes
# a call to SignInPromptController#get to determine if the user should see the sign in interstial.
# This is determined by how many signed out pagehits the user has executed an how recently they have
# last seen the insterstitial.  If the controller responds indicating the popup should appear, the
# React component will render its content.
# -->
#   <div data-react-class="ReactComponents.LoginInterstitial" data-react-props='{"allowFacebookSignIn":true,"allowAmazonSignIn":true,"overrideSignedOutPageCount":false,"path":{"signInUrl":"/user/sign_in","signUpUrl":"/user/sign_up","privacyUrl":"/about/privacy","termsUrl":"/about/terms","thirdPartyRedirectUrl":"/user/new?connect_prompt=true"}}'>
#    <noscript data-react-checksum="-1210117661" data-reactid=".wdviqvufzs">
#    </noscript>
#   </div>
#   <div id="overlay" onclick="Lightbox.hideBox()" style="display:none">
#   </div>
#   <div id="box" style="display:none">
#    <div class="xBackground js-closeModalIcon" id="close" onclick="Lightbox.hideBox()" title="Close this window">
#    </div>
#    <div id="boxContents">
#    </div>
#    <div id="boxContentsLeftovers" style="display:none">
#    </div>
#    <div class="clear">
#    </div>
#   </div>
#   <div id="fbSigninNotification" style="display:none;">
#    <p>
#     Welcome back. Just a moment while we sign you in to your Goodreads account.
#    </p>
#    <img alt="Login animation" src="https://s.gr-assets.com/assets/facebook/login_animation-085464711e6c1ed5ba287a2f40ba3343.gif"/>
#   </div>
#   <script>
#    //<![CDATA[
#     qcdata = {} || qcdata;
#       (function(){
#         var elem = document.createElement('script');
#         elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://pixel") + ".quantserve.com/aquant.js?a=p-0dUe_kJAjvkoY";
#         elem.async = true;
#         elem.type = "text/javascript";
#         var scpt = document.getElementsByTagName('script')[0];
#         scpt.parentNode.insertBefore(elem,scpt);
#       }());
#     var qcdata = {qacct: 'p-0dUe_kJAjvkoY'};
#   //]]>
#   </script>
#   <noscript>
#    <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-0dUe_kJAjvkoY.gif" style="display: none;" width="1"/>
#   </noscript>
#   <script>
#    //<![CDATA[
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "6035830", c3: "", c4: "", c5: "", c6: "", c15: ""});
#     (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#     })();
#   //]]>
#   </script>
#   <noscript>
#    <img alt="" height="0" src="https://sb.scorecardresearch.com/p?c1=2&amp;amp;c2=6035830&amp;amp;c3=&amp;amp;c4=&amp;amp;c5=&amp;amp;c6=&amp;amp;c15=&amp;amp;cv=2.0&amp;amp;cj=1" style="display: none" width="0"/>
#   </noscript>
#   <script>
#    //<![CDATA[
#     window.addEventListener("DOMContentLoaded", function() {
#       ReactStores.GoogleAdsStore.initializeWith({"targeting":{"sid":"osid.a7de86b6415b2d5948e38bfd99c47e4f","grsession":"osid.a7de86b6415b2d5948e38bfd99c47e4f","surface":"desktop","signedin":"false","gr_author":"false","author":[],"shelf":["adult","best","children","childrens","fiction","series","youngadult"],"tags":["244","3723","142","68","1","201","35"],"gtargeting":"1z141zd","resource":"List_1381"},"ads":{},"nativeAds":{}});  ReactStores.NotificationsStore.updateWith({});
#       ReactStores.CurrentUserStore.initializeWith({"currentUser":null});
#       ReactStores.FavoriteGenresStore.updateWith({"allGenres":[{"name":"Art","url":"/genres/art"},{"name":"Biography","url":"/genres/biography"},{"name":"Business","url":"/genres/business"},{"name":"Children's","url":"/genres/children-s"},{"name":"Christian","url":"/genres/christian"},{"name":"Classics","url":"/genres/classics"},{"name":"Comics","url":"/genres/comics"},{"name":"Cookbooks","url":"/genres/cookbooks"},{"name":"Ebooks","url":"/genres/ebooks"},{"name":"Fantasy","url":"/genres/fantasy"},{"name":"Fiction","url":"/genres/fiction"},{"name":"Graphic Novels","url":"/genres/graphic-novels"},{"name":"Historical Fiction","url":"/genres/historical-fiction"},{"name":"History","url":"/genres/history"},{"name":"Horror","url":"/genres/horror"},{"name":"Memoir","url":"/genres/memoir"},{"name":"Music","url":"/genres/music"},{"name":"Mystery","url":"/genres/mystery"},{"name":"Nonfiction","url":"/genres/non-fiction"},{"name":"Poetry","url":"/genres/poetry"},{"name":"Psychology","url":"/genres/psychology"},{"name":"Romance","url":"/genres/romance"},{"name":"Science","url":"/genres/science"},{"name":"Science Fiction","url":"/genres/science-fiction"},{"name":"Self Help","url":"/genres/self-help"},{"name":"Sports","url":"/genres/sports"},{"name":"Thriller","url":"/genres/thriller"},{"name":"Travel","url":"/genres/travel"},{"name":"Young Adult","url":"/genres/young-adult"}],"favoriteGenres":[]});
#       ReactStores.TabsStore.updateWith({"communitySpotlight":"groups"});
#
#     });
#   //]]>
#   </script>
#  </body>
# </html>

# %% [markdown]
# #### URL=`https://www.goodreads.com/list/show/1381.Best_Series`

# %% [markdown]
# #### title - > span itemprop = `name`
# #### author - > span itemprop = `author`
# #### rating - > span class = `minirating`
# #### score - > a href = `#`
# #### votes - > span class = `smallText uitext`

# %%
title=soup.find('span',attrs={'itemprop':'name'})
title.text
# Out:
# "Harry Potter and the Sorcerer's Stone (Harry Potter, #1)"

# %%
author=soup.find('span',attrs={'itemprop':'author'})
author.text
# Out:
# '\n\nJ.K. Rowling\n\n'

# %%
rating=soup.find('span',attrs={'class':'minirating'})
rating.text
# Out:
# ' 4.47 avg rating — 9,110,179 ratings'

# %%
score=soup.find('a',attrs={'href':'#'})
score.text
# Out:
# 'score: 344,121'

# %%
votes=soup.find('span',attrs={'class':'smallText uitext'})
votes.text
# Out:
# '\nscore: 344,121,\n              and\n3,472 people voted\n              \u2003\n              \n            '

# %% [markdown]
# #### All URL's

# %% [markdown]
# #### https://www.goodreads.com/list/show/1381.Best_Series?page=2
# #### https://www.goodreads.com/list/show/1381.Best_Series?page=3
# #### https://www.goodreads.com/list/show/1381.Best_Series?page=4
# #### https://www.goodreads.com/list/show/1381.Best_Series?page=5
# #### https://www.goodreads.com/list/show/1381.Best_Series?page=6

# %%
# Code



'''
URL='https://www.goodreads.com/list/show/1381.Best_Series?page=6'
'''
for i in range(1,7):
    print('https://www.goodreads.com/list/show/1381.Best_Series?page={}'.format(i))
# Out:
# https://www.goodreads.com/list/show/1381.Best_Series?page=1
# https://www.goodreads.com/list/show/1381.Best_Series?page=2
# https://www.goodreads.com/list/show/1381.Best_Series?page=3
# https://www.goodreads.com/list/show/1381.Best_Series?page=4
# https://www.goodreads.com/list/show/1381.Best_Series?page=5
# https://www.goodreads.com/list/show/1381.Best_Series?page=6

# %% [markdown]
# #### URL = `https://www.goodreads.com/list/show/1381.Best_Series`

# %% [markdown]
# #### title - > span itemprop = `name`
# #### author - > span itemprop = `author`
# #### rating - > span class = `minirating`
# #### score - > a href=`#`
# #### votes - > span class = `smallText uitext`

# %% [markdown]
# ### Web Scrapping

# %%
title=[]
author=[]
rating=[]
score=[]
votes=[]

for i in range(1,6):
    URL='https://www.goodreads.com/list/show/1381.Best_Series?page={}'.format(i)
    
    page=requests.get(URL)
    htmlcode=page.text
    soup=BeautifulSoup(htmlcode)
    
    for x in soup.find_all('td',attrs={'width':'100%'}):
        
        Title=x.find('span',attrs={'itemprop':'name'})
        if Title is None:
            title.append(np.NaN)
        else:
            title.append(Title.text)
            
        Author=x.find('span',attrs={'itemprop':'author'})
        if Author is None:
            author.append(np.NaN)
        else:
            author.append(Author.text)
            
        Rating=x.find('span',attrs={'class':'minirating'})
        if Rating is None:
            rating.append(np.NaN)
        else:
            rating.append(Rating.text)   
            
        Score=x.find('a',attrs={'href':'#'})
        if Score is None:
            score.append(np.NaN)
        else:
            score.append(Score.text)
            
        Votes=x.find('span',attrs={'class':'smallText uitext'})
        if Votes is None:
            votes.append(np.NaN)
        else:
            votes.append(Votes.text)

# %%
print(len(title))
print(len(author))
print(len(rating))
print(len(score))
print(len(votes))
# Out:
# 500
# 500
# 500
# 500
# 500

# %% [markdown]
# #### Create a DataFrame and save it in csv file

# %%
df = pd.DataFrame({'Title' :title,'Author':author,'Rating' : rating,'Score':score,'Votes':votes})

# %%
df
# Out:
#                                                  Title  \
# 0    Harry Potter and the Sorcerer's Stone (Harry P...
# 1    The Lightning Thief (Percy Jackson and the Oly...
# 2              The Hunger Games (The Hunger Games, #1)
# 3           City of Bones (The Mortal Instruments, #1)
# 4                            Divergent (Divergent, #1)
# ..                                                 ...
# 495                         Forgive My Fins (Fins, #1)
# 496     Nice Girls Don't Have Fangs (Jane Jameson, #1)
# 497           Prince of Thorns (The Broken Empire, #1)
# 498                        Splintered (Splintered, #1)
# 499                       Scythe (Arc of a Scythe, #1)
#
#                                           Author  \
# 0                           \n\nJ.K. Rowling\n\n
# 1        \n\nRick Riordan (Goodreads Author)\n\n
# 2                        \n\nSuzanne Collins\n\n
# 3     \n\nCassandra Clare (Goodreads Author)\n\n
# 4       \n\nVeronica Roth (Goodreads Author)\n\n
# ..                                           ...
# 495  \n\nTera Lynn Childs (Goodreads Author)\n\n
# 496      \n\nMolly Harper (Goodreads Author)\n\n
# 497    \n\nMark  Lawrence (Goodreads Author)\n\n
# 498       \n\nA.G. Howard (Goodreads Author)\n\n
# 499   \n\nNeal Shusterman (Goodreads Author)\n\n
#
#                                    Rating           Score  \
# 0     4.47 avg rating — 9,110,179 ratings  score: 344,121
# 1     4.29 avg rating — 2,637,162 ratings  score: 150,145
# 2     4.33 avg rating — 7,819,998 ratings  score: 143,135
# 3     4.08 avg rating — 1,893,536 ratings  score: 140,917
# 4     4.15 avg rating — 3,646,470 ratings  score: 134,930
# ..                                    ...             ...
# 495      3.84 avg rating — 17,213 ratings      score: 537
# 496      3.91 avg rating — 25,603 ratings      score: 535
# 497     3.85 avg rating — 107,950 ratings      score: 535
# 498      3.91 avg rating — 60,260 ratings      score: 535
# 499     4.33 avg rating — 241,267 ratings      score: 535
#
#                                                  Votes
# 0    \nscore: 344,121,\n              and\n3,472 pe...
# 1    \nscore: 150,145,\n              and\n1,540 pe...
# 2    \nscore: 143,135,\n              and\n1,465 pe...
# 3    \nscore: 140,917,\n              and\n1,443 pe...
# 4    \nscore: 134,930,\n              and\n1,390 pe...
# ..                                                 ...
# 495  \nscore: 537,\n              and\n7 people vot...
# 496  \nscore: 535,\n              and\n7 people vot...
# 497  \nscore: 535,\n              and\n7 people vot...
# 498  \nscore: 535,\n              and\n6 people vot...
# 499  \nscore: 535,\n              and\n6 people vot...
#
# [500 rows x 5 columns]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\bbhav\\Downloads'

# %%
df.to_csv(r"C:\Users\bbhav\Downloads\Best_Series.ipynb.csv", index = False)

# %%
df.head()
# Out:
#                                                Title  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...
# 1  The Lightning Thief (Percy Jackson and the Oly...
# 2            The Hunger Games (The Hunger Games, #1)
# 3         City of Bones (The Mortal Instruments, #1)
# 4                          Divergent (Divergent, #1)
#
#                                        Author  \
# 0                        \n\nJ.K. Rowling\n\n
# 1     \n\nRick Riordan (Goodreads Author)\n\n
# 2                     \n\nSuzanne Collins\n\n
# 3  \n\nCassandra Clare (Goodreads Author)\n\n
# 4    \n\nVeronica Roth (Goodreads Author)\n\n
#
#                                  Rating           Score  \
# 0   4.47 avg rating — 9,100,670 ratings  score: 343,625
# 1   4.29 avg rating — 2,633,971 ratings  score: 149,848
# 2   4.32 avg rating — 7,812,649 ratings  score: 142,841
# 3   4.08 avg rating — 1,892,338 ratings  score: 140,819
# 4   4.16 avg rating — 3,643,042 ratings  score: 134,735
#
#                                                Votes
# 0  \nscore: 343,625,\n              and\n3,467 pe...
# 1  \nscore: 149,848,\n              and\n1,537 pe...
# 2  \nscore: 142,841,\n              and\n1,462 pe...
# 3  \nscore: 140,819,\n              and\n1,442 pe...
# 4  \nscore: 134,735,\n              and\n1,388 pe...

# %%
df.to_excel(r"C:\Users\bbhav\Downloads\Best_Series.ipynb.xlsx")

# %% [markdown]
# # Extracting the Details using Regex

# %%
import numpy as np
import pandas as pd

import re
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\bbhav\Downloads\Best_Series.ipynb.csv")
df.head()
# Out:
#                                                Title  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...
# 1  The Lightning Thief (Percy Jackson and the Oly...
# 2            The Hunger Games (The Hunger Games, #1)
# 3         City of Bones (The Mortal Instruments, #1)
# 4                          Divergent (Divergent, #1)
#
#                                        Author  \
# 0                        \n\nJ.K. Rowling\n\n
# 1     \n\nRick Riordan (Goodreads Author)\n\n
# 2                     \n\nSuzanne Collins\n\n
# 3  \n\nCassandra Clare (Goodreads Author)\n\n
# 4    \n\nVeronica Roth (Goodreads Author)\n\n
#
#                                  Rating           Score  \
# 0   4.47 avg rating — 9,100,670 ratings  score: 343,625
# 1   4.29 avg rating — 2,633,971 ratings  score: 149,848
# 2   4.32 avg rating — 7,812,649 ratings  score: 142,841
# 3   4.08 avg rating — 1,892,338 ratings  score: 140,819
# 4   4.16 avg rating — 3,643,042 ratings  score: 134,735
#
#                                                Votes
# 0  \nscore: 343,625,\n              and\n3,467 pe...
# 1  \nscore: 149,848,\n              and\n1,537 pe...
# 2  \nscore: 142,841,\n              and\n1,462 pe...
# 3  \nscore: 140,819,\n              and\n1,442 pe...
# 4  \nscore: 134,735,\n              and\n1,388 pe...

# %% [markdown]
# ### Cleaning Author col

# %%
Author
# Out:
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/146374.Joseph_Delaney" itemprop="url"><span itemprop="name">Joseph Delaney</span></a>
# </div>
# </span>

# %%
# regex=r'\>[A-Za-z]+\s[A-Za-z]+'

# %%
df['Author']=df['Author'].str.replace('\n','').replace('\(Goodreads Author\)','',regex=True)

# %%
df.head()
# Out:
#                                                Title            Author  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...      J.K. Rowling
# 1  The Lightning Thief (Percy Jackson and the Oly...     Rick Riordan
# 2            The Hunger Games (The Hunger Games, #1)   Suzanne Collins
# 3         City of Bones (The Mortal Instruments, #1)  Cassandra Clare
# 4                          Divergent (Divergent, #1)    Veronica Roth
#
#                                  Rating           Score  \
# 0   4.47 avg rating — 9,100,670 ratings  score: 343,625
# 1   4.29 avg rating — 2,633,971 ratings  score: 149,848
# 2   4.32 avg rating — 7,812,649 ratings  score: 142,841
# 3   4.08 avg rating — 1,892,338 ratings  score: 140,819
# 4   4.16 avg rating — 3,643,042 ratings  score: 134,735
#
#                                                Votes
# 0  \nscore: 343,625,\n              and\n3,467 pe...
# 1  \nscore: 149,848,\n              and\n1,537 pe...
# 2  \nscore: 142,841,\n              and\n1,462 pe...
# 3  \nscore: 140,819,\n              and\n1,442 pe...
# 4  \nscore: 134,735,\n              and\n1,388 pe...

# %% [markdown]
# ### Splitting Rating col

# %%
df[['Ratings','Reviews']]=df['Rating'].str.split('—',expand=True)

# %%
df.head()
# Out:
#                                                Title            Author  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...      J.K. Rowling
# 1  The Lightning Thief (Percy Jackson and the Oly...     Rick Riordan
# 2            The Hunger Games (The Hunger Games, #1)   Suzanne Collins
# 3         City of Bones (The Mortal Instruments, #1)  Cassandra Clare
# 4                          Divergent (Divergent, #1)    Veronica Roth
#
#                                  Rating           Score  \
# 0   4.47 avg rating — 9,100,670 ratings  score: 343,625
# 1   4.29 avg rating — 2,633,971 ratings  score: 149,848
# 2   4.32 avg rating — 7,812,649 ratings  score: 142,841
# 3   4.08 avg rating — 1,892,338 ratings  score: 140,819
# 4   4.16 avg rating — 3,643,042 ratings  score: 134,735
#
#                                                Votes            Ratings  \
# 0  \nscore: 343,625,\n              and\n3,467 pe...   4.47 avg rating
# 1  \nscore: 149,848,\n              and\n1,537 pe...   4.29 avg rating
# 2  \nscore: 142,841,\n              and\n1,462 pe...   4.32 avg rating
# 3  \nscore: 140,819,\n              and\n1,442 pe...   4.08 avg rating
# 4  \nscore: 134,735,\n              and\n1,388 pe...   4.16 avg rating
#
#               Reviews
# 0   9,100,670 ratings
# 1   2,633,971 ratings
# 2   7,812,649 ratings
# 3   1,892,338 ratings
# 4   3,643,042 ratings

# %%
# Dropping Rating col

df.drop('Rating',axis=1,inplace=True)

# %%
df.head()
# Out:
#                                                Title            Author  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...      J.K. Rowling
# 1  The Lightning Thief (Percy Jackson and the Oly...     Rick Riordan
# 2            The Hunger Games (The Hunger Games, #1)   Suzanne Collins
# 3         City of Bones (The Mortal Instruments, #1)  Cassandra Clare
# 4                          Divergent (Divergent, #1)    Veronica Roth
#
#             Score                                              Votes  \
# 0  score: 343,625  \nscore: 343,625,\n              and\n3,467 pe...
# 1  score: 149,848  \nscore: 149,848,\n              and\n1,537 pe...
# 2  score: 142,841  \nscore: 142,841,\n              and\n1,462 pe...
# 3  score: 140,819  \nscore: 140,819,\n              and\n1,442 pe...
# 4  score: 134,735  \nscore: 134,735,\n              and\n1,388 pe...
#
#              Ratings             Reviews
# 0   4.47 avg rating    9,100,670 ratings
# 1   4.29 avg rating    2,633,971 ratings
# 2   4.32 avg rating    7,812,649 ratings
# 3   4.08 avg rating    1,892,338 ratings
# 4   4.16 avg rating    3,643,042 ratings

# %% [markdown]
# ### Cleaning Score col

# %%
df['Score']=df['Score'].str.replace('score: ','')

# %%
df.Score=df.Score.apply(lambda x: int(x.replace(',','')) if ',' in x else int(x))

# %%
df.head()
# Out:
#                                                Title            Author  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...      J.K. Rowling
# 1  The Lightning Thief (Percy Jackson and the Oly...     Rick Riordan
# 2            The Hunger Games (The Hunger Games, #1)   Suzanne Collins
# 3         City of Bones (The Mortal Instruments, #1)  Cassandra Clare
# 4                          Divergent (Divergent, #1)    Veronica Roth
#
#     Score                                              Votes  \
# 0  343625  \nscore: 343,625,\n              and\n3,467 pe...
# 1  149848  \nscore: 149,848,\n              and\n1,537 pe...
# 2  142841  \nscore: 142,841,\n              and\n1,462 pe...
# 3  140819  \nscore: 140,819,\n              and\n1,442 pe...
# 4  134735  \nscore: 134,735,\n              and\n1,388 pe...
#
#              Ratings             Reviews
# 0   4.47 avg rating    9,100,670 ratings
# 1   4.29 avg rating    2,633,971 ratings
# 2   4.32 avg rating    7,812,649 ratings
# 3   4.08 avg rating    1,892,338 ratings
# 4   4.16 avg rating    3,643,042 ratings

# %% [markdown]
# ### Cleaning Votes col

# %%
regex=r'(.*)\s?people'

df['Votes']=df['Votes'].apply(lambda x:re.findall(regex,x))

# %%
df.Votes=df.Votes.apply(lambda x:''.join(x))

# %%
df.Votes=df.Votes.apply(lambda x: int(x.replace(',','')) if ',' in x else int(x))

# %%
df.head()
# Out:
#                                                Title            Author  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...      J.K. Rowling
# 1  The Lightning Thief (Percy Jackson and the Oly...     Rick Riordan
# 2            The Hunger Games (The Hunger Games, #1)   Suzanne Collins
# 3         City of Bones (The Mortal Instruments, #1)  Cassandra Clare
# 4                          Divergent (Divergent, #1)    Veronica Roth
#
#     Score  Votes            Ratings             Reviews
# 0  343625   3467   4.47 avg rating    9,100,670 ratings
# 1  149848   1537   4.29 avg rating    2,633,971 ratings
# 2  142841   1462   4.32 avg rating    7,812,649 ratings
# 3  140819   1442   4.08 avg rating    1,892,338 ratings
# 4  134735   1388   4.16 avg rating    3,643,042 ratings

# %% [markdown]
# ### Cleaning Ratings col

# %%
df['Ratings']=df['Ratings'].str.replace('avg rating','').replace('really liked it','',regex=True)

# %%
df['Ratings']=df['Ratings'].apply(lambda x: float(x))

# %%
df.head()
# Out:
#                                                Title            Author  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...      J.K. Rowling
# 1  The Lightning Thief (Percy Jackson and the Oly...     Rick Riordan
# 2            The Hunger Games (The Hunger Games, #1)   Suzanne Collins
# 3         City of Bones (The Mortal Instruments, #1)  Cassandra Clare
# 4                          Divergent (Divergent, #1)    Veronica Roth
#
#     Score  Votes  Ratings             Reviews
# 0  343625   3467     4.47   9,100,670 ratings
# 1  149848   1537     4.29   2,633,971 ratings
# 2  142841   1462     4.32   7,812,649 ratings
# 3  140819   1442     4.08   1,892,338 ratings
# 4  134735   1388     4.16   3,643,042 ratings

# %% [markdown]
# ### Cleaning Reviews col

# %%
df['Reviews']=df['Reviews'].str.replace('ratings','')

# %%
df['Reviews']=df['Reviews'].apply(lambda x: int(x.replace(',','')) if ',' in x else int(x))

# %%
df.head()
# Out:
#                                                Title            Author  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...      J.K. Rowling
# 1  The Lightning Thief (Percy Jackson and the Oly...     Rick Riordan
# 2            The Hunger Games (The Hunger Games, #1)   Suzanne Collins
# 3         City of Bones (The Mortal Instruments, #1)  Cassandra Clare
# 4                          Divergent (Divergent, #1)    Veronica Roth
#
#     Score  Votes  Ratings  Reviews
# 0  343625   3467     4.47  9100670
# 1  149848   1537     4.29  2633971
# 2  142841   1462     4.32  7812649
# 3  140819   1442     4.08  1892338
# 4  134735   1388     4.16  3643042

# %% [markdown]
# ### Creating Overview col

# %%
df['Overview']=df['Ratings'].apply(lambda x: 'Excellent' if x>=4.5 else('Good' if x>=4 else('Average' if x>=3 else x)))

# %%
df.head()
# Out:
#                                                Title            Author  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...      J.K. Rowling
# 1  The Lightning Thief (Percy Jackson and the Oly...     Rick Riordan
# 2            The Hunger Games (The Hunger Games, #1)   Suzanne Collins
# 3         City of Bones (The Mortal Instruments, #1)  Cassandra Clare
# 4                          Divergent (Divergent, #1)    Veronica Roth
#
#     Score  Votes  Ratings  Reviews Overview
# 0  343625   3467     4.47  9100670     Good
# 1  149848   1537     4.29  2633971     Good
# 2  142841   1462     4.32  7812649     Good
# 3  140819   1442     4.08  1892338     Good
# 4  134735   1388     4.16  3643042     Good

# %% [markdown]
# ### Creating Hashtag col

# %%
Title
# Out:
# <span aria-level="4" itemprop="name" role="heading">Scythe (Arc of a Scythe, #1)</span>

# %%
df['Hashtag']='#1'

# %%
df.head()
# Out:
#                                                Title            Author  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...      J.K. Rowling
# 1  The Lightning Thief (Percy Jackson and the Oly...     Rick Riordan
# 2            The Hunger Games (The Hunger Games, #1)   Suzanne Collins
# 3         City of Bones (The Mortal Instruments, #1)  Cassandra Clare
# 4                          Divergent (Divergent, #1)    Veronica Roth
#
#     Score  Votes  Ratings  Reviews Overview Hashtag
# 0  343625   3467     4.47  9100670     Good      #1
# 1  149848   1537     4.29  2633971     Good      #1
# 2  142841   1462     4.32  7812649     Good      #1
# 3  140819   1442     4.08  1892338     Good      #1
# 4  134735   1388     4.16  3643042     Good      #1

# %%
df['Hashtag'][90:91]='#0'

# %%
df.head()
# Out:
#                                                Title            Author  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...      J.K. Rowling
# 1  The Lightning Thief (Percy Jackson and the Oly...     Rick Riordan
# 2            The Hunger Games (The Hunger Games, #1)   Suzanne Collins
# 3         City of Bones (The Mortal Instruments, #1)  Cassandra Clare
# 4                          Divergent (Divergent, #1)    Veronica Roth
#
#     Score  Votes  Ratings  Reviews Overview Hashtag
# 0  343625   3467     4.47  9100670     Good      #1
# 1  149848   1537     4.29  2633971     Good      #1
# 2  142841   1462     4.32  7812649     Good      #1
# 3  140819   1442     4.08  1892338     Good      #1
# 4  134735   1388     4.16  3643042     Good      #1

# %%
df.Hashtag.value_counts()
# Out:
# #1    499
# #0      1
# Name: Hashtag, dtype: int64

# %%
df['Hashtag'][467:468]='#2'

# %%
df.head()
# Out:
#                                                Title            Author  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...      J.K. Rowling
# 1  The Lightning Thief (Percy Jackson and the Oly...     Rick Riordan
# 2            The Hunger Games (The Hunger Games, #1)   Suzanne Collins
# 3         City of Bones (The Mortal Instruments, #1)  Cassandra Clare
# 4                          Divergent (Divergent, #1)    Veronica Roth
#
#     Score  Votes  Ratings  Reviews Overview Hashtag
# 0  343625   3467     4.47  9100670     Good      #1
# 1  149848   1537     4.29  2633971     Good      #1
# 2  142841   1462     4.32  7812649     Good      #1
# 3  140819   1442     4.08  1892338     Good      #1
# 4  134735   1388     4.16  3643042     Good      #1

# %%
##regex=r'\W\d'
##df['Hashtag']=df['Title'].apply(lambda x:re.findall(regex,x))

# %%
##df.head()

# %%
df.Hashtag.value_counts()
# Out:
# #1    498
# #0      1
# #2      1
# Name: Hashtag, dtype: int64

# %% [markdown]
# ### Creating Denotes col

# %%
df['Denotes']=df['Hashtag'].apply(lambda x: 'First Book' if x=='#1' else('Prequel' if x=='#0' else('Prequel of the next Book' if x=='#2' else x)))

# %%
df.Denotes=df.Denotes.apply(lambda x:''.join(x))

# %%
df.head()
# Out:
#                                                Title            Author  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...      J.K. Rowling
# 1  The Lightning Thief (Percy Jackson and the Oly...     Rick Riordan
# 2            The Hunger Games (The Hunger Games, #1)   Suzanne Collins
# 3         City of Bones (The Mortal Instruments, #1)  Cassandra Clare
# 4                          Divergent (Divergent, #1)    Veronica Roth
#
#     Score  Votes  Ratings  Reviews Overview Hashtag     Denotes
# 0  343625   3467     4.47  9100670     Good      #1  First Book
# 1  149848   1537     4.29  2633971     Good      #1  First Book
# 2  142841   1462     4.32  7812649     Good      #1  First Book
# 3  140819   1442     4.08  1892338     Good      #1  First Book
# 4  134735   1388     4.16  3643042     Good      #1  First Book

# %%
df.Hashtag=df.Hashtag.apply(lambda x:''.join(x))

# %%
df.head()
# Out:
#                                                Title            Author  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...      J.K. Rowling
# 1  The Lightning Thief (Percy Jackson and the Oly...     Rick Riordan
# 2            The Hunger Games (The Hunger Games, #1)   Suzanne Collins
# 3         City of Bones (The Mortal Instruments, #1)  Cassandra Clare
# 4                          Divergent (Divergent, #1)    Veronica Roth
#
#     Score  Votes  Ratings  Reviews Overview Hashtag     Denotes
# 0  343625   3467     4.47  9100670     Good      #1  First Book
# 1  149848   1537     4.29  2633971     Good      #1  First Book
# 2  142841   1462     4.32  7812649     Good      #1  First Book
# 3  140819   1442     4.08  1892338     Good      #1  First Book
# 4  134735   1388     4.16  3643042     Good      #1  First Book

# %% [markdown]
# ### Creating Series col

# %%
regex=r'\((.*)?,'

df['Series']=df['Title'].apply(lambda x:re.findall(regex,x))

# %%
df.Series=df.Series.apply(lambda x:''.join(x))

# %%
df.head()
# Out:
#                                                Title            Author  \
# 0  Harry Potter and the Sorcerer's Stone (Harry P...      J.K. Rowling
# 1  The Lightning Thief (Percy Jackson and the Oly...     Rick Riordan
# 2            The Hunger Games (The Hunger Games, #1)   Suzanne Collins
# 3         City of Bones (The Mortal Instruments, #1)  Cassandra Clare
# 4                          Divergent (Divergent, #1)    Veronica Roth
#
#     Score  Votes  Ratings  Reviews Overview Hashtag     Denotes  \
# 0  343625   3467     4.47  9100670     Good      #1  First Book
# 1  149848   1537     4.29  2633971     Good      #1  First Book
# 2  142841   1462     4.32  7812649     Good      #1  First Book
# 3  140819   1442     4.08  1892338     Good      #1  First Book
# 4  134735   1388     4.16  3643042     Good      #1  First Book
#
#                             Series
# 0                     Harry Potter
# 1  Percy Jackson and the Olympians
# 2                 The Hunger Games
# 3           The Mortal Instruments
# 4                        Divergent

# %% [markdown]
# ### Cleaning Title col

# %%
regex=r'(.*)\('

df['Title']=df['Title'].apply(lambda x:re.findall(regex,x))

# %%
df['Title']=df['Title'].apply(lambda x:''.join(x))

# %%
df.head()
# Out:
#                                     Title            Author   Score  Votes  \
# 0  Harry Potter and the Sorcerer's Stone       J.K. Rowling  343625   3467
# 1                    The Lightning Thief      Rick Riordan   149848   1537
# 2                       The Hunger Games    Suzanne Collins  142841   1462
# 3                          City of Bones   Cassandra Clare   140819   1442
# 4                              Divergent     Veronica Roth   134735   1388
#
#    Ratings  Reviews Overview Hashtag     Denotes  \
# 0     4.47  9100670     Good      #1  First Book
# 1     4.29  2633971     Good      #1  First Book
# 2     4.32  7812649     Good      #1  First Book
# 3     4.08  1892338     Good      #1  First Book
# 4     4.16  3643042     Good      #1  First Book
#
#                             Series
# 0                     Harry Potter
# 1  Percy Jackson and the Olympians
# 2                 The Hunger Games
# 3           The Mortal Instruments
# 4                        Divergent

# %%
# replacing the empty rows with nan value

df=df.replace(r"^\s*$",np.nan,regex=True)

# %%
df
# Out:
#                                       Title             Author   Score  Votes  \
# 0    Harry Potter and the Sorcerer's Stone        J.K. Rowling  343625   3467
# 1                      The Lightning Thief       Rick Riordan   149848   1537
# 2                         The Hunger Games     Suzanne Collins  142841   1462
# 3                            City of Bones    Cassandra Clare   140819   1442
# 4                                Divergent      Veronica Roth   134735   1388
# ..                                      ...                ...     ...    ...
# 495                  The Kiss of Deception    Mary E. Pearson      533      7
# 496                                     NaN           H.A. Rey     532      8
# 497                          If I Were You   Lisa Renee Jones      532      6
# 498                        Amelia Bedelia         Fritz Siebel     531      8
# 499                   Revenge of the Witch      Joseph Delaney     530      6
#
#      Ratings  Reviews Overview Hashtag     Denotes  \
# 0       4.47  9100670     Good      #1  First Book
# 1       4.29  2633971     Good      #1  First Book
# 2       4.32  7812649     Good      #1  First Book
# 3       4.08  1892338     Good      #1  First Book
# 4       4.16  3643042     Good      #1  First Book
# ..       ...      ...      ...     ...         ...
# 495     3.96   120398  Average      #1  First Book
# 496     4.16   133829     Good      #1  First Book
# 497     4.12    25807     Good      #1  First Book
# 498     4.18    87885     Good      #1  First Book
# 499     4.00    47230     Good      #1  First Book
#
#                                          Series
# 0                                  Harry Potter
# 1               Percy Jackson and the Olympians
# 2                              The Hunger Games
# 3                        The Mortal Instruments
# 4                                     Divergent
# ..                                          ...
# 495                      The Remnant Chronicles
# 496                                         NaN
# 497                                  Inside Out
# 498                              Amelia Bedelia
# 499  The Last Apprentice / Wardstone Chronicles
#
# [500 rows x 10 columns]

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#                                     Title            Author   Score  Votes  \
# 0  Harry Potter and the Sorcerer's Stone       J.K. Rowling  343625   3467
# 1                    The Lightning Thief      Rick Riordan   149848   1537
# 2                       The Hunger Games    Suzanne Collins  142841   1462
# 3                          City of Bones   Cassandra Clare   140819   1442
# 4                              Divergent     Veronica Roth   134735   1388
#
#    Ratings  Reviews Overview Hashtag     Denotes  \
# 0     4.47  9100670     Good      #1  First Book
# 1     4.29  2633971     Good      #1  First Book
# 2     4.32  7812649     Good      #1  First Book
# 3     4.08  1892338     Good      #1  First Book
# 4     4.16  3643042     Good      #1  First Book
#
#                             Series
# 0                     Harry Potter
# 1  Percy Jackson and the Olympians
# 2                 The Hunger Games
# 3           The Mortal Instruments
# 4                        Divergent

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index                                   Title            Author   Score  \
# 0      0  Harry Potter and the Sorcerer's Stone       J.K. Rowling  343625
# 1      1                    The Lightning Thief      Rick Riordan   149848
# 2      2                       The Hunger Games    Suzanne Collins  142841
# 3      3                          City of Bones   Cassandra Clare   140819
# 4      4                              Divergent     Veronica Roth   134735
#
#    Votes  Ratings  Reviews Overview Hashtag     Denotes  \
# 0   3467     4.47  9100670     Good      #1  First Book
# 1   1537     4.29  2633971     Good      #1  First Book
# 2   1462     4.32  7812649     Good      #1  First Book
# 3   1442     4.08  1892338     Good      #1  First Book
# 4   1388     4.16  3643042     Good      #1  First Book
#
#                             Series
# 0                     Harry Potter
# 1  Percy Jackson and the Olympians
# 2                 The Hunger Games
# 3           The Mortal Instruments
# 4                        Divergent

# %%
df.drop(["index"],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                     Title            Author   Score  Votes  \
# 0  Harry Potter and the Sorcerer's Stone       J.K. Rowling  343625   3467
# 1                    The Lightning Thief      Rick Riordan   149848   1537
# 2                       The Hunger Games    Suzanne Collins  142841   1462
# 3                          City of Bones   Cassandra Clare   140819   1442
# 4                              Divergent     Veronica Roth   134735   1388
#
#    Ratings  Reviews Overview Hashtag     Denotes  \
# 0     4.47  9100670     Good      #1  First Book
# 1     4.29  2633971     Good      #1  First Book
# 2     4.32  7812649     Good      #1  First Book
# 3     4.08  1892338     Good      #1  First Book
# 4     4.16  3643042     Good      #1  First Book
#
#                             Series
# 0                     Harry Potter
# 1  Percy Jackson and the Olympians
# 2                 The Hunger Games
# 3           The Mortal Instruments
# 4                        Divergent

# %%
#1 means the first book of the Series 
#0 means the prequel of the Series
#2 means the second book or prequel of the next book

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     482 non-null    object
#  1   Author    482 non-null    object
#  2   Score     482 non-null    int64
#  3   Votes     482 non-null    int64
#  4   Ratings   482 non-null    float64
#  5   Reviews   482 non-null    int64
#  6   Overview  482 non-null    object
#  7   Hashtag   482 non-null    object
#  8   Denotes   482 non-null    object
#  9   Series    482 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 37.8+ KB

# %%
df.describe()
# Out:
#                Score        Votes     Ratings       Reviews
# count     482.000000   482.000000  482.000000  4.820000e+02
# mean     7609.813278    81.404564    4.029253  2.913123e+05
# std     23032.364643   235.105736    0.201229  7.540373e+05
# min       530.000000     6.000000    3.450000  2.700000e+01
# 25%       830.500000    10.000000    3.900000  3.949550e+04
# 50%      1417.500000    17.500000    4.030000  8.801550e+04
# 75%      4216.500000    47.000000    4.160000  2.314195e+05
# max    343625.000000  3467.000000    4.680000  9.100670e+06

# %%
# Analysis

# %%
x=df.groupby(["Votes"])[['Title']]
x.first()
# Out:
#                                         Title
# Votes
# 6                                  Awakening
# 7               New England Witch Chronicles
# 8           Zoroastrians' Fight for Survival
# 9                     Trust: A New Beginning
# 10                                The Rising
# ...                                       ...
# 1388                               Divergent
# 1442                           City of Bones
# 1462                        The Hunger Games
# 1537                     The Lightning Thief
# 3467   Harry Potter and the Sorcerer's Stone
#
# [144 rows x 1 columns]

# %%
l=df.groupby(['Title'])[['Ratings']]

# %%
l.first()
# Out:
#                                    Ratings
# Title
# 1st to Die                            4.09
# A Bear Called Paddington              4.23
# A Court of Thorns and Roses           4.20
# A Darker Shade of Magic               4.07
# A Discovery of Witches                4.02
# ...                                    ...
# Wool Omnibus                          4.21
# Written in Red                        4.25
# You Slay Me                           3.99
# Zoroastrians' Fight for Survival      4.62
# ttyl                                  3.45
#
# [481 rows x 1 columns]

# %%
df.isnull().sum()
# Out:
# Title       0
# Author      0
# Score       0
# Votes       0
# Ratings     0
# Reviews     0
# Overview    0
# Hashtag     0
# Denotes     0
# Series      0
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df.head()
# Out:
#                                     Title            Author   Score  Votes  \
# 0  Harry Potter and the Sorcerer's Stone       J.K. Rowling  343625   3467
# 1                    The Lightning Thief      Rick Riordan   149848   1537
# 2                       The Hunger Games    Suzanne Collins  142841   1462
# 3                          City of Bones   Cassandra Clare   140819   1442
# 4                              Divergent     Veronica Roth   134735   1388
#
#    Ratings  Reviews Overview Hashtag     Denotes  \
# 0     4.47  9100670     Good      #1  First Book
# 1     4.29  2633971     Good      #1  First Book
# 2     4.32  7812649     Good      #1  First Book
# 3     4.08  1892338     Good      #1  First Book
# 4     4.16  3643042     Good      #1  First Book
#
#                             Series
# 0                     Harry Potter
# 1  Percy Jackson and the Olympians
# 2                 The Hunger Games
# 3           The Mortal Instruments
# 4                        Divergent

# %% [markdown]
# ### Univariate

# %% [markdown]
# ### > I want to know which Author has written highest number of Books

# %%
plt.figure(figsize=(10,3))
df["Author"].value_counts().head(15).plot.bar()
plt.xlabel('Author')
plt.ylabel(('Count'))
plt.title('Number of Books Written by Author')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation:

# %% [markdown]
#  >* From the above bar plot we observed that there are three Authors who wrote maximum number of Books, that means the three Authors are repeated in the column

# %% [markdown]
# ### > I want to know the percentage of individual Overview

# %%
# pie plot

df['Overview'].value_counts().plot.pie(autopct="%.2f%%")
plt.title('Overview on Ratings')
plt.legend(['Good(>=4)','Average(>=3)','Excellent(>=4.5)'])
plt.show()

# %% [markdown]
# #### Observation

# %% [markdown]
# >* From the above pie chart we observed that most of the Books have Good Overview, means most of the books have ratings between 4 and 4.5

# %% [markdown]
# ### > I want to know the count of Overview

# %%
sns.countplot(x=df['Overview'], data=df)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Observation:

# %% [markdown]
# >* From the above bar plot we can observe that tere are more than 250 Good Overview, more than 150 Average Overview and less than 25 Excellent Overview.

# %% [markdown]
# ### I want to show the relation between `Hashtag` and `Denotes` columns

# %%
plt.figure(figsize=(6,6))
df["Denotes"].value_counts().plot.pie(explode=[0,0,0.9],autopct='%.3f')
plt.title('Books Denotation')
plt.legend(['#1 - First Book','#0 - Prequel','#2 - Prequel of the next Book'])
plt.show()

# %% [markdown]
# ### Observation:

# %% [markdown]
# >* From the above pie plot we obseved that most of Books are denoted as #1 which are the First Book of the Series

# %% [markdown]
# ### > I want to know the Density of Votes

# %%
sns.distplot(df['Votes'],kde=True)
plt.title('Density of Votes')
plt.show()

# %% [markdown]
# >* From the above plot we can observe that most of the Books got Votes between 0 to 500 and very few Books got Votes greater than 1000

# %% [markdown]
# ### To know the frequency of Ratings

# %%
plt.hist(df['Ratings'])
plt.xlabel('Ratings')
plt.title('Frequency of Ratings')
plt.show()

# %% [markdown]
# ### Observation

# %% [markdown]
# * This hist plot denotes Frequency distribution of Ratings

# %% [markdown]
# * We can observe that 4.12 rating has highest frequency

# %% [markdown]
# ## Bivariate

# %% [markdown]
# ### Categorical and Numerical

# %% [markdown]
# ### > I want to know which Series got Votes above 1000

# %%
sns.barplot(x=df['Title'].head(6),y=df['Votes'],data=df)
plt.xticks(rotation = 90)
plt.title('Title and Votes')
plt.show()

# %% [markdown]
# >* From the above bar plot we can observe that Harry Potter and the Sorcerer's Stone Book got Votes above 3000 and 4 more Books more above 1000

# %% [markdown]
# ### > Relation between Votes and Score

# %%
# Scatter plot

sns.scatterplot(x=df['Score'],y=df['Votes'],data=df)
plt.title('Votes and Score')
plt.show()

# %% [markdown]
# >* There is perfect positive correlation between Score and Votes nearly equal to 1 . So they depend on each other

# %% [markdown]
# ### > Relation between Ratings and Reviews

# %%
x=df['Ratings']
y=df['Reviews']
plt.xlabel('Ratings')
plt.ylabel('Reviews(In Lakhs)')
plt.title('Ratings and Reviews')
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ### Observation

# %% [markdown]
# >* From the above plot we can see Ratings and Reviews are not correlated, and they does'nt depend on each other

# %% [markdown]
# ### Box plot

# %%
sns.boxplot(data=df,x='Overview', y='Ratings')
plt.xticks(rotation=90)
plt.title('Boxplot of Ratings and Overview')
plt.show()

# %% [markdown]
# >* From the above plot we can see that there are outlayers only for Good and Average.

# %% [markdown]
# ### violin plot

# %%
sns.violinplot(y=df['Votes'],x=df['Overview'],data=df)
plt.xticks(rotation = 90)
plt.title('violin plot of Votes and Overview')
plt.show()

# %% [markdown]
# ### Observation

# %% [markdown]
# >* From the above plot we can see that Average Overviewed Series have highest density of Votes

# %% [markdown]
# ### Multivariate

# %%
v=df.select_dtypes(include='number')
v
# Out:
#       Score  Votes  Ratings  Reviews
# 0    343625   3467     4.47  9100670
# 1    149848   1537     4.29  2633971
# 2    142841   1462     4.32  7812649
# 3    140819   1442     4.08  1892338
# 4    134735   1388     4.16  3643042
# ..      ...    ...      ...      ...
# 477     535      6     4.33   240664
# 478     533      7     3.96   120398
# 479     532      6     4.12    25807
# 480     531      8     4.18    87885
# 481     530      6     4.00    47230
#
# [482 rows x 4 columns]

# %% [markdown]
# ### heatmap

# %%
sns.heatmap(v.corr(),annot=True,linewidth=.5,linecolor='black')
# Out:
# <AxesSubplot:>

# %% [markdown]
# >* From the above heatmap plot we can observe that all numerical values are positively correlated. Score and Votes are highly correlated which means as Votes increases Score increases.Ratings and Reviews are less correlated which is nearly equal to zero

# %% [markdown]
# ### pair plot

# %%
sns.pairplot(df.head(50))
plt.show()

# %% [markdown]
# ### Observation

# %% [markdown]
# >* From the above pair plot we observed the both distribution of single variable and relation between two variable

# %% [markdown]
# ### Scenario

# %%
a=float(input('Enter any Ratings greater than 4 but less than 5:'))
b=int(input('Enter any Votes greater than 1000 but less less than 3500:'))
c=int(input('Enter any Score greater than 200000 but less than 344000:'))
d=int(input('Enter any Reviews greater than 7900000 but less than 9100000:'))
# Out:
# Enter any Ratings greater than 4 but less than 5:4.12
# Enter any Votes greater than 1000 but less less than 3500:3000
# Enter any Score greater than 200000 but less than 344000:300000
# Enter any Reviews greater than 7900000 but less than 9100000:8000000

# %%
df[(df['Ratings']>a)&(df['Votes']>b)&(df['Score']>c)&(df['Reviews']>d)]
# Out:
#                                     Title        Author   Score  Votes  \
# 0  Harry Potter and the Sorcerer's Stone   J.K. Rowling  343625   3467
#
#    Ratings  Reviews Overview Hashtag     Denotes        Series
# 0     4.47  9100670     Good      #1  First Book  Harry Potter
